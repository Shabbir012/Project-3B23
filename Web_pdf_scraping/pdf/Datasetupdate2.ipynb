# %%
#install libraries
# !pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading PyMuPDF-1.24.2-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 25.8 MB/s eta 0:00:00
# Collecting PyMuPDFb==1.24.1 (from pymupdf)
#   Downloading PyMuPDFb-1.24.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 26.0 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, pymupdf
# Successfully installed PyMuPDFb-1.24.1 pymupdf-1.24.2

# %%
#import the libraries
import fitz
import nltk
import re
import pandas as pd
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#input the path of the pdf
File_Path = "/content/2020_OTRENTIWINKLER_VIRTUALREALITYANDRETAILERS_POSSIBILITIESANDLIMITATIONSFROMASYSTEMATICREVIEW.pdf"

# %%
#this is a class that represents the document
pdf = fitz.open(File_Path)

# %%
#get basic information about the page
pdf.metadata

# %%
#get the number of pages of the pdf file
pdf.page_count

# %%
#Entire book as text starting from 0 to last page
# get all the text as list
from sys import ps1
def get_book_content(pdf_file):
  num_page = pdf_file.page_count
  book_content = []
  for i in range(4,8):
    page = pdf_file.load_page(i)
    page_text =  page.get_text().replace("\n", " ")
    raw_text = page_text.replace("\t", " ")

    book_content.append(raw_text)

  return book_content

# %%
#call get_book_content function
book = get_book_content(pdf)
book

# %%
# @title
#tokenize into sentences
sentencelist = []
for i in range(0, 4):
# Create a sentence tokenizer
  tokenizer = nltk.sent_tokenize(book[i])

# Print the extracted sentences
  for sentence in tokenizer:
    sentencelist.append(sentence)

len(sentencelist)
# Out:
# 92

# %%
#convert list to data frame
df = pd.DataFrame(sentencelist, columns = ['Text'])
df
# Out:
#                                                  Text
# 0   VI INTERNATIONAL SYMPOSIUM ON INNOVATION AND T...
# 1   Fluxograma    Figura 2 – Fluxograma de identif...
# 2                                                  3.
# 3   RESULTS AND DISCUSSION (ARIAL 12)    The publi...
# 4   The results and discussions are presented in t...
# ..                                                ...
# 87  4HANCOCK, Peter A.; PEPE, Aaron A.; MURPHY, La...
# 88  Ergonomics in design, v. 13, n. 1, p. 8-14, 2005.
# 89                5SCHOLZ, Joachim; DUFFY, Katherine.
# 90  We ARe at home: How augmented reality reshapes...
# 91  Journal of Retailing and Consumer Services,  v...
#
# [92 rows x 1 columns]

# %%
#drop irrelevent information
df = df.drop([77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91])
df
# Out:
#                                                  Text
# 0   VI INTERNATIONAL SYMPOSIUM ON INNOVATION AND T...
# 1   Fluxograma    Figura 2 – Fluxograma de identif...
# 2                                                  3.
# 3   RESULTS AND DISCUSSION (ARIAL 12)    The publi...
# 4   The results and discussions are presented in t...
# ..                                                ...
# 72  The user´s purchase journey pleasure can be en...
# 73  The interface between the product and the user...
# 74  There was no comparison between the same 3D vi...
# 75  VR is an important tool that can stimulate psy...
# 76  VR technologies have a good maturity and marke...
#
# [77 rows x 1 columns]

# %%
#save to a csv file
df.to_csv("Datasetupdate2")
